# %% [markdown]
# # 作業1
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# https://www.kaggle.com/aaronschlegel/austin-animal-center-shelter-outcomes-and
#
# 1. 你選的這組資料為何重要
# 當今社會中，有許多家庭都會飼養寵物作陪伴，也因社會中積極提倡領養代替購買，有越來越多人選擇從收容所中領養寵物，假如將收容所間的流浪動物資訊進行統整與編號，能夠使有意領養寵物的人方便查詢，也能讓收容所控管寵物數量及轉院更加便利。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# The dataset is provided by the wonderful folks at the Austin Animal Center, the largest no-kill animal shelter in the United States. The AAC makes available the data on the Austin Open Data Portal. More information on the dataset can be found one the Shelter Outcomes page.
#
# A simple script to programmatically extract the Austin Animal Center's shelter outcome dataset through the Socrata Open Data Access (SODA) API can be found as a Github Gist here. The shelter outcomes endpoint is https://data.austintexas.gov/resource/hcup-htgu.json.
# 3. 蒐集而來的資料型態為何
# 結構化資料 : animal_id、animal_type、breed…
#
# 4. 這組資料想解決的問題如何評估
# Sentiment analysis in a variety of forms  分類問題 ML 模型
# Cupoy內參考: https://docs.aws.amazon.com/zh_tw/machine-learning/latest/dg/evaluating_models.html
# 可以分析多少年齡以上，或是身體狀況較差的流浪動物較不易被收養，可集中於同一收容所，較易照顧及管理

# %% [markdown]
# # 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 我認為，提升業績最主要的方法就是提升載客率以及如何降低空車時間已達到最大效益，所以如何知道各個時間與地段的叫車平均人數來分配車隊位置是我們優先要處理的問題
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 時間及區域的不同都會對叫車情況產生影響，我們能蒐集車隊中各區域與時段的的歷史叫車紀錄來分析1並預測未來車隊在各時段與地區的分配情況
# 3. 蒐集而來的資料型態為何
# Datetime、string
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 用分析結果與將來幾天內的叫車紀錄比對來評估準確率及效益

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_squared_error(y,yp):
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

MSE = mean_squared_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MSE))
# Out:
# The Mean absolute error is 278.774

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 13.155

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 278.774
# The Mean absolute error is 13.155
